# %% [markdown]
# ### 0. importy :)

# %%
import numpy as np
import matplotlib.pyplot as plt
from pathlib import Path
from PIL import Image
import cv2
import kagglehub as kg
from torch.utils.data import Dataset
from skimage.filters import threshold_otsu
from skimage.morphology import remove_small_objects, binary_dilation, disk

# %% [markdown]
# ### 1. ścieżki

# %%
path = kg.dataset_download("andrewmvd/lung-and-colon-cancer-histopathological-images")

print("Path to dataset files:", path)
# Out:
# Path to dataset files: /home/oligus/.cache/kagglehub/datasets/andrewmvd/lung-and-colon-cancer-histopathological-images/versions/1

# %%
DATA_DIR = Path("/home/oligus/.cache/kagglehub/datasets/andrewmvd/lung-and-colon-cancer-histopathological-images/versions/1/lung_colon_image_sets")
LUNG_DIR = Path("/home/oligus/.cache/kagglehub/datasets/andrewmvd/lung-and-colon-cancer-histopathological-images/versions/1/lung_colon_image_sets/lung_image_sets")
COLON_DIR = Path("/home/oligus/.cache/kagglehub/datasets/andrewmvd/lung-and-colon-cancer-histopathological-images/versions/1/lung_colon_image_sets/colon_image_sets")

# %%
print(f"ścieżka surowa do wszystkich danych: {DATA_DIR}")
print(f"czy surowa ścieżka istnieje? {DATA_DIR.exists()}")
print(f"full ścieżka: {DATA_DIR.absolute()}")
# Out:
# ścieżka surowa do wszystkich danych: /home/oligus/.cache/kagglehub/datasets/andrewmvd/lung-and-colon-cancer-histopathological-images/versions/1/lung_colon_image_sets
# czy surowa ścieżka istnieje? False
# full ścieżka: /home/oligus/.cache/kagglehub/datasets/andrewmvd/lung-and-colon-cancer-histopathological-images/versions/1/lung_colon_image_sets

# %% [markdown]
# ## CHECKLIST !!

# %%
# TODO
# open zdjecia colon i lung cancer (jpeg) i zmapować na siatce
# i gdzie są metadane w ogóle??? HALOOOO

# poćwiczyć kolorki (kanały)
# podstawowe operacje resize, crop, convert to grayscale

# funkcja do thumbnail (get_thumbnail → napisać sama !!)
# read region  →czytanie dowolnej rozdzielczości (ale to są jpg więc chyba nie jednak)
